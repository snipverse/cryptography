# %% [markdown]
# <a href="https://colab.research.google.com/github/snipverse/cryptography/blob/main/caesar_cipher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#caesar cipher
def encrypt (text, shift):
  result = ""
  for char in text:
    if char.isupper():
      result += chr((ord(char)-65 + shift) % 26 + 65)
    elif char.islower():
      result += chr((ord(char)-97 + shift) % 26 + 97)
    else:
      result += char

  return result

def decrypt (text, shift):
  result = ""
  for char in text:
    if char.isupper():
      result += chr((ord(char)-65 - shift) % 26 + 65)
    elif char.islower():
      result += chr((ord(char)-97 - shift) % 26 + 97)
    else:
      result += char

  return result

message = input("Enter the message: ")
shift = int(input("Enter the shift: "))

encrypted = encrypt(message, shift)
print("Encrypted message: ", encrypted)

decrypted = decrypt(encrypted, shift)
print("Decrypted message: ", decrypted)
# Out:
# Enter the message: sachin
# Enter the shift: 3
# Encrypted message:  vdfklq
# Decrypted message:  sachin
