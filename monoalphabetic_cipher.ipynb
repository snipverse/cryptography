# %% [markdown]
# <a href="https://colab.research.google.com/github/snipverse/cryptography/blob/main/monoalphabetic_cipher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import string, random

def create_key():
    letters = list(string.ascii_lowercase)
    shuffled = letters.copy()
    random.shuffle(shuffled)
    return dict(zip(letters, shuffled))

def encrypt(text, key):
    result = ""
    for ch in text:
        if ch.islower():
            result += key[ch]
        elif ch.isupper():
            result += key[ch.lower()].upper()
        else:
            result += ch
    return result

def decrypt(text, key):
    inv = {v:k for k,v in key.items()}
    return encrypt(text, inv)

key = create_key()
msg = input("Enter message: ")

enc = encrypt(msg, key)
print("Encrypted:", enc)

dec = decrypt(enc, key)
print("Decrypted:", dec)
# Out:
# Enter message: hi, sachin
# Encrypted: uj, xhqujd
# Decrypted: hi, sachin
